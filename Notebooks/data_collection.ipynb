# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
import pandas as pd

# from src.data.data_fetcher import DataFetcher

# fetcher = StockDataFetcher()

# %%
# def print_nested_dict(data, indent=0):
#     """
#     Recursively prints a nested dictionary in a structured format.

#     Args:
#         data (dict): Dictionary to print.
#         indent (int): Indentation level for formatting.
#     """
#     for key, value in data.items():
#         if isinstance(value, dict):
#             print(" " * indent + f"{key}:")
#             print_nested_dict(value, indent + 4)
#         else:
#             print(" " * indent + f"{key}: {value}")

# def test_full_stock_info(ticker: str):
#     """
#     Test function to fetch and print all stock information.

#     Args:
#         ticker (str): Stock symbol (e.g., 'AAPL')
#     """
#     fetcher = StockDataFetcher()
    
#     result = fetcher.get_full_stock_info(ticker)

#     print("\n" + "=" * 50)
#     print(f"FULL STOCK DATA FOR: {ticker.upper()}")
#     print("=" * 50 + "\n")

#     # Check error first
#     if result["error"]:
#         print("Error:", result["error"])
#         return

#     # Print everything
#     print_nested_dict(result)

# # print(test_full_stock_info("AAPL"))

# %% [markdown]
# # Testing validate ticker function

# %%
# ticker = "aapl"

# if fetcher.validate_ticker(ticker):
#     print("Valid ticker ✅")
# else:
#     print("Invalid ticker ❌")

# %% [markdown]
# # Testing fetch historical function

# %%
# result = fetcher.fetch_historical("AAPL")

# if result["error"]:
#     print("Error:", result["error"])
# else:
#     df = result["data"]

# df.head(5)

# %% [markdown]
# # Testing fetch info function

# %%
# result = fetcher.fetch_info("AAPL")

# if result["error"]:
#     print("Error:", result["error"])
# else:
#     df = pd.DataFrame([result["data"]])

# df

# %%
# result = fetcher.fetch_info("AAPL")

# if result["error"]:
#     print("Error:", result["error"])
# else:
#     df = ([result["data"]])

# df

# %% [markdown]
# # Testing fetch financials function

# %%
# result = fetcher.fetch_financials("AAPL")

# if result["error"]:
#     print("Error:", result["error"])
# else:
#     print([result["balance_sheet"]])

# %%
# print([result['cash_flow']])

# %%
# print([result['income_stmt']])

# %%
# print([result['quarterly_cash_flow']])

# %%
# from src.data.main import GrowthConsistencyAnalyzer

# analyzer = GrowthConsistencyAnalyzer()

# # Use the class directly
# ticker = "AAPL"
# result = analyzer.count_positive_growth_quarters(ticker, metric="both", num_quarters=8)

# # This now returns the dictionary directly
# print(f"Positive quarters: {result['positive_quarters']}")  # This will work now
# print(f"Consistency score: {result['consistency_score']}")

# %%
# from src.data.main import count_positive_growth_quarters

# # Your code will work now
# ticker = "AAPL"
# result = count_positive_growth_quarters(ticker, metric="both", num_quarters=8)

# print(f"=== Growth Consistency Analysis for {ticker} ===")
# print(f"Positive growth quarters (last 8): {result['positive_quarters']}")
# print(f"Revenue positive: {result['revenue_positive']}/8")
# print(f"Earnings positive: {result['earnings_positive']}/8")
# print(f"Consistency Score: {result['consistency_score']}")
# print(f"Consistency Level: {result['consistency_level']}")

# # Your scoring logic
# consistent_quarters = result['positive_quarters']

# print(f"\n=== Your Scoring System ===")
# print(f"Consistent quarters: {consistent_quarters}")

# if consistent_quarters >= 7:
#     consistency_score = 20
#     print(f"Result: Very consistent → Score = {consistency_score}")
# elif consistent_quarters >= 5:
#     consistency_score = 15
#     print(f"Result: Mostly consistent → Score = {consistency_score}")
# elif consistent_quarters >= 3:
#     consistency_score = 10
#     print(f"Result: Somewhat consistent → Score = {consistency_score}")
# else:
#     consistency_score = 5
#     print(f"Result: Inconsistent → Score = {consistency_score}")

# %%
# from src.data.growth_consistancy_score import get_growth_consistency_score
# score = get_growth_consistency_score("AAPL")

# print(score)
# # {'positive_quarters': 6, 'consistency_score': 15}

# %%
# from src.data.dividend_consistancy_score import get_dividend_score
# result = get_dividend_score("AAPL")

# print(result)

# %%
# test_pipeline.py

import pprint

from src.data.data_fetcher import DataFetcher
from src.data.metrics_engine import get_final_stock_data


def run_test(ticker: str):
    print(f"\n=== Testing for ticker: {ticker} ===\n")

    # -----------------------------------
    # STEP 1: VALIDATE TICKER
    # -----------------------------------
    is_valid = DataFetcher.validate_ticker_static(ticker)

    if not is_valid:
        print(f"❌ Invalid ticker: {ticker}")
        return

    print("✅ Ticker is valid\n")

    # -----------------------------------
    # STEP 2: FETCH DATA
    # -----------------------------------
    fetcher = DataFetcher(ticker)
    data = fetcher.get_full_stock_data()

    if not data.get("success"):
        print("⚠️ Partial errors during fetch:")
        pprint.pprint(data.get("errors"))
        print()

    print("✅ Data fetched successfully\n")

    # -----------------------------------
    # STEP 3: COMPUTE METRICS
    # -----------------------------------
    enriched_data = get_final_stock_data(data)

    print("✅ Metrics computed successfully\n")

    # -----------------------------------
    # STEP 4: PRINT FINAL STRUCTURE
    # -----------------------------------
    print("========== FINAL DATA STRUCTURE ==========\n")

    _print_structure(enriched_data)

    print("\n========== FULL DATA (VALUES) ==========\n")

    pprint.pprint(enriched_data, depth=3, compact=False)


# -----------------------------------
# HELPER: PRINT STRUCTURE ONLY
# -----------------------------------

def _print_structure(data, indent=0):
    spacing = " " * indent

    if isinstance(data, dict):
        for key, value in data.items():
            print(f"{spacing}{key}:")
            _print_structure(value, indent + 4)

    elif hasattr(data, "shape"):  # pandas DataFrame / Series
        print(f"{spacing}<{type(data).__name__} shape={data.shape}>")

    else:
        print(f"{spacing}{type(data).__name__}")


# -----------------------------------
# RUN TEST
# -----------------------------------

if __name__ == "__main__":
    run_test("AAPL")   # change ticker here
# Out:
# === Testing for ticker: AAPL ===
#
# ✅ Ticker is valid
#
# ✅ Data fetched successfully
#
# ✅ Metrics computed successfully
#
# ========== FINAL DATA STRUCTURE ==========
#
# ticker:
#     str
# info:
#     symbol:
#         str
#     long_name:
#         str
#     short_name:
#         str
#     sector:
#         str
#     industry:
#         str
#     current_price:
#         float
#     previous_close:
#         float
#     pe_ratio:
#         float
#     forward_pe:
#         float
#     peg_ratio:
#         float
#     price_to_book:
#         float
#     ev_to_ebitda:
#         float
#     price_to_sales:
#         float
#     profit_margin:
#         float
#     operating_margin:
#         float
#     gross_margin:
#         float
#     roe:
#         float
#     roa:
#         float
#     trailing_eps:
#         float
#     forward_eps:
#         float
#     revenue_growth:
#         float
#     earnings_growth:
#         float
#     quarterly_earnings_growth:
#         float
#     debt_to_equity:
#         float
#     current_ratio:
#         float
#     quick_ratio:
#         float
#     free_cash_flow:
#         float
#     operating_cash_flow:
#         float
#     beta:
#         float
#     market_cap:
#         float
#     volume:
#         float
#     avg_volume:
#         float
#     dividend_yield:
#         float
#     payout_ratio:
#         float
#     eps_growth:
#         float
# history:
#     data:
#         <DataFrame shape=(251, 7)>
#     ma50:
#         <float64 shape=()>
#     ma200:
#         <float64 shape=()>
#     rsi_14:
#         <float64 shape=()>
#     macd:
#         <float64 shape=()>
#     signal:
#         <float64 shape=()>
#     avg_volume_20d:
#         <float64 shape=()>
# dividends:
#     data:
#         <Series shape=(90,)>
#     dividend_years:
#         int
#     has_cuts:
#         bool
#     dividend_cagr:
#         <float64 shape=()>
# financials:
#     data:
#         <DataFrame shape=(33, 6)>
#     positive_quarters:
#         int
# errors:
# success:
#     bool
#
# ========== FULL DATA (VALUES) ==========
#
# {'dividends': {'data': Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
# 1988-05-16 00:00:00-04:00    0.000714
#                                ...
# 2025-02-10 00:00:00-05:00    0.250000
# 2025-05-12 00:00:00-04:00    0.260000
# 2025-08-11 00:00:00-04:00    0.260000
# 2025-11-10 00:00:00-05:00    0.260000
# 2026-02-09 00:00:00-05:00    0.260000
# Name: Dividends, Length: 90, dtype: float64,
#                'dividend_cagr': np.float64(-26.89),
#                'dividend_years': 5,
#                'has_cuts': True},
#  'errors': {},
#  'financials': {'data':                                                       2026-03-31  \
# tax_effect_of_unusual_items                                  NaN
# tax_rate_for_calcs                                           NaN
# normalized_ebitda                                            NaN
# net_income_from_continuing_operation_net_minori...           NaN
# reconciled_depreciation                                      NaN
# reconciled_cost_of_revenue                                   NaN
# ebitda                                                       NaN
# ebit                                                         NaN
# normalized_income                                            NaN
# net_income_from_continuing_and_discontinued_ope...           NaN
# total_expenses                                               NaN
# total_operating_income_as_reported                           NaN
# diluted_average_shares                              1.472587e+10
# basic_average_shares                                1.467328e+10
# diluted_eps                                         2.010000e+00
# basic_eps                                           2.020000e+00
# diluted_ni_availto_com_stockholders                          NaN
# net_income_common_stockholders                               NaN
# net_income                                                   NaN
# net_income_including_noncontrolling_interests                NaN
# net_income_continuous_operations                             NaN
# tax_provision                                                NaN
# pretax_income                                                NaN
# other_income_expense                                         NaN
# other_non_operating_income_expenses                          NaN
# operating_income                                             NaN
# operating_expense                                            NaN
# research_and_development                                     NaN
# selling_general_and_administration                           NaN
# gross_profit                                                 NaN
# cost_of_revenue                                              NaN
# total_revenue                                                NaN
# operating_revenue                                            NaN
#
#                                                       2025-12-31  \
# tax_effect_of_unusual_items                         0.000000e+00
# tax_rate_for_calcs                                  1.750000e-01
# normalized_ebitda                                   5.406600e+10
# net_income_from_continuing_operation_net_minori...  4.209700e+10
# reconciled_depreciation                             3.214000e+09
# reconciled_cost_of_revenue                          7.452500e+10
# ebitda                                              5.406600e+10
# ebit                                                5.085200e+10
# normalized_income                                   4.209700e+10
# net_income_from_continuing_and_discontinued_ope...  4.209700e+10
# total_expenses                                      9.290400e+10
# total_operating_income_as_reported                  5.085200e+10
# diluted_average_shares                              1.481036e+10
# basic_average_shares                                1.474816e+10
# diluted_eps                                         2.840000e+00
# basic_eps                                           2.850000e+00
# diluted_ni_availto_com_stockholders                 4.209700e+10
# net_income_common_stockholders                      4.209700e+10
# net_income                                          4.209700e+10
# net_income_including_noncontrolling_interests       4.209700e+10
# net_income_continuous_operations                    4.209700e+10
# tax_provision                                       8.905000e+09
# pretax_income                                       5.100200e+10
# other_income_expense                                1.500000e+08
# other_non_operating_income_expenses                 1.500000e+08
# operating_income                                    5.085200e+10
# operating_expense                                   1.837900e+10
# research_and_development                            1.088700e+10
# selling_general_and_administration                  7.492000e+09
# gross_profit                                        6.923100e+10
# cost_of_revenue                                     7.452500e+10
# total_revenue                                       1.437560e+11
# operating_revenue                                   1.437560e+11
#
#                                                       2025-09-30  \
# tax_effect_of_unusual_items                         0.000000e+00
# tax_rate_for_calcs                                  1.627240e-01
# normalized_ebitda                                   3.555400e+10
# net_income_from_continuing_operation_net_minori...  2.746600e+10
# reconciled_depreciation                             3.127000e+09
# reconciled_cost_of_revenue                          5.412500e+10
# ebitda                                              3.555400e+10
# ebit                                                3.242700e+10
# normalized_income                                   2.746600e+10
# net_income_from_continuing_and_discontinued_ope...  2.746600e+10
# total_expenses                                      7.003900e+10
# total_operating_income_as_reported                  3.242700e+10
# diluted_average_shares                              1.486361e+10
# basic_average_shares                                1.481531e+10
# diluted_eps                                         1.850000e+00
# basic_eps                                           1.850000e+00
# diluted_ni_availto_com_stockholders                 2.746600e+10
# net_income_common_stockholders                      2.746600e+10
# net_income                                          2.746600e+10
# net_income_including_noncontrolling_interests       2.746600e+10
# net_income_continuous_operations                    2.746600e+10
# tax_provision                                       5.338000e+09
# pretax_income                                       3.280400e+10
# other_income_expense                                3.770000e+08
# other_non_operating_income_expenses                 3.770000e+08
# operating_income                                    3.242700e+10
# operating_expense                                   1.591400e+10
# research_and_development                            8.866000e+09
# selling_general_and_administration                  7.048000e+09
# gross_profit                                        4.834100e+10
# cost_of_revenue                                     5.412500e+10
# total_revenue                                       1.024660e+11
# operating_revenue                                   1.024660e+11
#
#                                                       2025-06-30  \
# tax_effect_of_unusual_items                         0.000000e+00
# tax_rate_for_calcs                                  1.640000e-01
# normalized_ebitda                                   3.103200e+10
# net_income_from_continuing_operation_net_minori...  2.343400e+10
# reconciled_depreciation                             2.830000e+09
# reconciled_cost_of_revenue                          5.031800e+10
# ebitda                                              3.103200e+10
# ebit                                                2.820200e+10
# normalized_income                                   2.343400e+10
# net_income_from_continuing_and_discontinued_ope...  2.343400e+10
# total_expenses                                      6.583400e+10
# total_operating_income_as_reported                  2.820200e+10
# diluted_average_shares                              1.494818e+10
# basic_average_shares                                1.490289e+10
# diluted_eps                                         1.570000e+00
# basic_eps                                           1.570000e+00
# diluted_ni_availto_com_stockholders                 2.343400e+10
# net_income_common_stockholders                      2.343400e+10
# net_income                                          2.343400e+10
# net_income_including_noncontrolling_interests       2.343400e+10
# net_income_continuous_operations                    2.343400e+10
# tax_provision                                       4.597000e+09
# pretax_income                                       2.803100e+10
# other_income_expense                               -1.710000e+08
# other_non_operating_income_expenses                -1.710000e+08
# operating_income                                    2.820200e+10
# operating_expense                                   1.551600e+10
# research_and_development                            8.866000e+09
# selling_general_and_administration                  6.650000e+09
# gross_profit                                        4.371800e+10
# cost_of_revenue                                     5.031800e+10
# total_revenue                                       9.403600e+10
# operating_revenue                                   9.403600e+10
#
#                                                       2025-03-31    2024-12-31
# tax_effect_of_unusual_items                         0.000000e+00  0.000000e+00
# tax_rate_for_calcs                                  1.550000e-01  1.470000e-01
# normalized_ebitda                                   3.225000e+10  4.591200e+10
# net_income_from_continuing_operation_net_minori...  2.478000e+10  3.633000e+10
# reconciled_depreciation                             2.661000e+09  3.080000e+09
# reconciled_cost_of_revenue                          5.049200e+10  6.602500e+10
# ebitda                                              3.225000e+10  4.591200e+10
# ebit                                                2.958900e+10  4.283200e+10
# normalized_income                                   2.478000e+10  3.633000e+10
# net_income_from_continuing_and_discontinued_ope...  2.478000e+10  3.633000e+10
# total_expenses                                      6.577000e+10  8.146800e+10
# total_operating_income_as_reported                  2.958900e+10  4.283200e+10
# diluted_average_shares                              1.505613e+10           NaN
# basic_average_shares                                1.499408e+10           NaN
# diluted_eps                                         1.650000e+00           NaN
# basic_eps                                           1.650000e+00           NaN
# diluted_ni_availto_com_stockholders                 2.478000e+10  3.633000e+10
# net_income_common_stockholders                      2.478000e+10  3.633000e+10
# net_income                                          2.478000e+10  3.633000e+10
# net_income_including_noncontrolling_interests       2.478000e+10  3.633000e+10
# net_income_continuous_operations                    2.478000e+10  3.633000e+10
# tax_provision                                       4.530000e+09  6.254000e+09
# pretax_income                                       2.931000e+10  4.258400e+10
# other_income_expense                               -2.790000e+08 -2.480000e+08
# other_non_operating_income_expenses                -2.790000e+08 -2.480000e+08
# operating_income                                    2.958900e+10  4.283200e+10
# operating_expense                                   1.527800e+10  1.544300e+10
# research_and_development                            8.550000e+09  8.268000e+09
# selling_general_and_administration                  6.728000e+09  7.175000e+09
# gross_profit                                        4.486700e+10  5.827500e+10
# cost_of_revenue                                     5.049200e+10  6.602500e+10
# total_revenue                                       9.535900e+10  1.243000e+11
# operating_revenue                                   9.535900e+10  1.243000e+11  ,
#                 'positive_quarters': 1},
#  'history': {'avg_volume_20d': np.float64(46605931.3),
#              'data':                   open        high         low       close    volume  \
# Date
# 2025-05-05  202.218654  203.214314  197.349875  198.026917  69018500
# 2025-05-06  197.349874  199.779272  196.165035  197.648560  51216500
# 2025-05-07  198.305688  198.574520  192.411380  195.398361  68536700
# 2025-05-08  196.861978  199.181869  193.835162  196.632980  50478900
# 2025-05-09  198.136449  199.669760  196.682778  197.668488  36453900
# ...                ...         ...         ...         ...       ...
# 2026-04-28  272.339996  273.230011  268.660004  270.709991  40018900
# 2026-04-29  267.549988  271.040009  267.040009  270.170013  30047900
# 2026-04-30  270.500000  276.000000  268.140015  271.350006  91848200
# 2026-05-01  278.859985  287.220001  278.369995  280.140015  79844600
# 2026-05-04  279.654999  280.630005  274.860107  276.829987  45414226
#
#             dividends  stock_splits
# Date
# 2025-05-05        0.0           0.0
# 2025-05-06        0.0           0.0
# 2025-05-07        0.0           0.0
# 2025-05-08        0.0           0.0
# 2025-05-09        0.0           0.0
# ...               ...           ...
# 2026-04-28        0.0           0.0
# 2026-04-29        0.0           0.0
# 2026-04-30        0.0           0.0
# 2026-05-01        0.0           0.0
# 2026-05-04        0.0           0.0
#
# [251 rows x 7 columns],
#              'ma200': np.float64(255.23860427856445),
#              'ma50': np.float64(261.46359985351563),
#              'macd': np.float64(4.559334441028625),
#              'rsi_14': np.float64(65.7452838146777),
#              'signal': np.float64(3.6757389946452212)},
#  'info': {'avg_volume': 44124766.0,
#           'beta': 1.065,
#           'current_price': 276.83,
#           'current_ratio': 1.07,
#           'debt_to_equity': 79.548,
#           'dividend_yield': 0.39,
#           'earnings_growth': 0.218,
#           'eps_growth': 15.545520581113802,
#           'ev_to_ebitda': 25.821,
#           'forward_eps': 9.54406,
#           'forward_pe': 29.005474,
#           'free_cash_flow': 101090746368.0,
#           'gross_margin': 0.47862,
#           'industry': 'Consumer Electronics',
#           'long_name': 'Apple Inc.',
#           'market_cap': 4060455895040.0,
#           'operating_cash_flow': 140222005248.0,
#           'operating_margin': 0.32275,
#           'payout_ratio': 0.1259,
#           'pe_ratio': 33.514526,
#           'peg_ratio': 2.52,
#           'previous_close': 280.25,
#           'price_to_book': 46.153713,
#           'price_to_sales': 8.994413,
#           'profit_margin': 0.27152002,
#           'quarterly_earnings_growth': 0.194,
#           'quick_ratio': 0.906,
#           'revenue_growth': 0.166,
#           'roa': 0.26229,
#           'roe': 1.4147099,
#           'sector': 'Technology',
#           'short_name': 'Apple Inc.',
#           'symbol': 'AAPL',
#           'trailing_eps': 8.26,
#           'volume': 45414226.0},
#  'success': True,
#  'ticker': 'AAPL'}
